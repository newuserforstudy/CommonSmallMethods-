# %%
import torch
from PIL import Image
from PIL import ImageFilter
import numpy as np 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
img1 = Image.open("/home/lessmart/桌面/mae-class/images/val/false/val_false_40000.jpg")
img2 = Image.open("/home/lessmart/桌面/mae-class/images/val/false/val_false_40000.jpg")

img1_array = np.array(img1)
img2_array = np.array(img2)

# %%
sum(sum(sum(img1_array-img2_array)))
# Out:
# 0

# %%
img3 = Image.open("/media/lessmart/work/sdh/similar_cls2/images/train/ch_hand/000021.jpg")
img4 = Image.open("/media/lessmart/work/sdh/similar_cls2/images/train/ch_print/000021.jpg")

img3 = img3.filter(ImageFilter.FIND_EDGES)  # 边缘检测
img4 = img4.filter(ImageFilter.FIND_EDGES)

plt.imshow(img3)
plt.show()
plt.imshow(img4)
plt.show()
# img3_array = np.array(img3)
# img4_array = np.array(img4)

# %%
# sum(sum(sum(img3_array-img4_array)))
