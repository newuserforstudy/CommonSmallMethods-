# %%
my_data = b'\\\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x1f\x00\x00\x00\x00\x00\x00\x00\xbf\t\x00\x00\x00\x00\x00\x00\xd6R\x05\x00\x00\x00\x00\x00+o\x01\x00\x00\x00\x00\x00D\x1d\x00\x00\x00\x00\x00\x00\xc2\\\x05\x00\x00\x00\x00\x000A?\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x1f\x00\x00\x00\x00\x00\x00\x00\x8b\t\x00\x00\x00\x00\x00\x00\x895\x05\x00\x00\x00\x00\x00ag\x01\x00\x00\x00\x00\x00\x83\x00\x00\x00\x00\x00\x00\x00A?\x05\x00\x00\x00\x00\x00/H\x00p\r\xf8\x0f\x80\x0fP\x0f\xf0\x0e\x90\x0eH\x0e\xe8\r\xa0\r\xe0\x0f\xc8\x0f\x98\x0f\xb0\x0fh\x0f8\x0f \x0f\x08\x0f\xd8\x0e\xa8\x0e\xc0\x0ex\x0e`\x0e\x00\x0e\x18\x0e0\x0e\xd0\r\xb8\r\x88\rp\r\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xc0\x00\x0b\x08\x00a\x00\xf8\x01\x01\x11\x00\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n'

# %%
my_data
type(my_data)
# Out:
# bytes

# %%
len(my_data)
# Out:
# 8342

# %%
import sys

# %%
sys.getsizeof(my_data)
# Out:
# 8375

# %%
len(my_data)
import struct
import numpy as np

# %%
tple = struct.unpack( 'i', my_data )
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-43-9333938924ff> in <module>()
# ----> 1 tple = struct.unpack( 'i', my_data )
#
# error: unpack requires a buffer of 4 bytes

# %%
my_array = np.array( tple, dtype=np.float32 )

# %%
my_array
# Out:
# array([1., 2., 3., 4.], dtype=float32)
